# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Alle Daten

# %%
#data = pd.read_excel("karneval-kalorien_bereinigt_mit_Hersteller.xlsx")

# %% [markdown]
# # Ausgewählte Daten inkl. fotos

# %%
data = pd.read_excel("Data.xlsx")

# %%
data.head()
# Out:
#   Supermarkt                         Hersteller          Name  \
# 0       Aldi  Ludwig Schokolade GmbH und Co. KG          Race
# 1       Aldi  Ludwig Schokolade GmbH und Co. KG    Choco Bits
# 2       Aldi  Ludwig Schokolade GmbH und Co. KG  Coconut Bits
# 3       Aldi  Ludwig Schokolade GmbH und Co. KG        GET'IT
# 4       Aldi  Ludwig Schokolade GmbH und Co. KG   Crispy Bits
#
#    davon Zucker in g  Fett in g  Kalorien in kcal  Unnamed: 6  Unnamed: 7  \
# 0               56.8       19.7               467         NaN         NaN
# 1               64.2       16.3               452         NaN         NaN
# 2               48.1       24.7               481         NaN         NaN
# 3               44.0       23.0               484         NaN         NaN
# 4               51.0       24.0               485         NaN         NaN
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         NaN         NaN          NaN          NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 19
# 0          NaN
# 1         16.3
# 2          NaN
# 3          NaN
# 4          NaN

# %%
#data = data[['Name','Hersteller', 'Kalorien in kcal']]

# %%
#data = data.reindex(data.index.rename(['Platzierung']))

# %%
#data.index = data['Name']

# %%
#data.drop(columns=data['data'], axis=1)

# %% [markdown]
# ## Name/Rename Index

# %%
#data.index.name = 'Index'

# %%
#data.set_index(data['Name'])

# %% [markdown]
# ## Get Length of Pandas Rows

# %%
len(data.index)
# Out:
# 37

# %% [markdown]
# ## Add Foto-Columns

# %%
#data['Fotos'] = "" #np.arange(len(data.index))

# %%
data.head()
# Out:
#   Supermarkt                         Hersteller          Name  \
# 0       Aldi  Ludwig Schokolade GmbH und Co. KG          Race
# 1       Aldi  Ludwig Schokolade GmbH und Co. KG    Choco Bits
# 2       Aldi  Ludwig Schokolade GmbH und Co. KG  Coconut Bits
# 3       Aldi  Ludwig Schokolade GmbH und Co. KG        GET'IT
# 4       Aldi  Ludwig Schokolade GmbH und Co. KG   Crispy Bits
#
#    davon Zucker in g  Fett in g  Kalorien in kcal  Unnamed: 6  Unnamed: 7  \
# 0               56.8       19.7               467         NaN         NaN
# 1               64.2       16.3               452         NaN         NaN
# 2               48.1       24.7               481         NaN         NaN
# 3               44.0       23.0               484         NaN         NaN
# 4               51.0       24.0               485         NaN         NaN
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         NaN         NaN          NaN          NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 19
# 0          NaN
# 1         16.3
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# ## Add Fotos

# %%
#data['Fotos'] = data.Fotos.apply(lambda x: "https://bilder.ams3.cdn.digitaloceanspaces.com/Aldi_SelectionMini_Chrispy-Bits__DSC1486.jpg")
#data.at[0, 'Fotos'] = "https://bilder.ams3.cdn.digitaloceanspaces.com/Aldi_SelectionMini_Chrispy-Bits__DSC1486.jpg"
#data.at[1, 'Fotos'] = "https://bilder.ams3.cdn.digitaloceanspaces.com/LIDL_MC_Choco_Caramel_DSC1480.jpg"
#data.at[2, 'Fotos'] = "https://bilder.ams3.cdn.digitaloceanspaces.com/Aldi_Peanut-Bits_DSC1491.jpg"

# %%
data.loc['Fotos'] = np.nan
# Out:
# /Users/mstauber/Data/Anaconda/anaconda/envs/data/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# ## Change https to http

# %%
#data['Foto'] = data.Foto.apply(lambda x: x.replace("https", "http"))

# %% [markdown]
# ## Result

# %%
data.head()
# Out:
#    Fotos          Name                         Hersteller  Kalorien in kcal
# 0    NaN          Race  Ludwig Schokolade GmbH und Co. KG             467.0
# 1    NaN    Choco Bits  Ludwig Schokolade GmbH und Co. KG             452.0
# 2    NaN  Coconut Bits  Ludwig Schokolade GmbH und Co. KG             481.0
# 3    NaN        GET'IT  Ludwig Schokolade GmbH und Co. KG             484.0
# 4    NaN   Crispy Bits  Ludwig Schokolade GmbH und Co. KG             485.0

# %% [markdown]
# ## Rearrange Columns

# %%
data = data[['Fotos','Name','Hersteller','Kalorien in kcal']]

# %%
data
# Out:
#        Fotos                                         Name  \
# 0        NaN                                         Race
# 1        NaN                                   Choco Bits
# 2        NaN                                 Coconut Bits
# 3        NaN                                       GET'IT
# 4        NaN                                  Crispy Bits
# 5        NaN                                Hazelnut Bits
# 6        NaN                                  Peanut Bits
# 7        NaN                              Choco & Caramel
# 8        NaN                               Peanut & Choco
# 9        NaN                         Smooth Caramel Bites
# 10       NaN                                Caramel Choco
# 11       NaN                      Caramel & Biscuts Bites
# 12       NaN                      Peanuts & Caramel Bites
# 13       NaN                                 Peanut Choco
# 14       NaN                                       Creamy
# 15       NaN                                Peanuts MINIS
# 16       NaN                                  SIMBA minis
# 17       NaN                              Crack 'n' Snack
# 18       NaN                                         Mars
# 19       NaN                                     MILKYWAY
# 20       NaN                                     Snickers
# 21       NaN                                   Lion White
# 22       NaN                                       Bounty
# 23       NaN                                         Twix
# 24       NaN                                         Nuts
# 25       NaN                              nutella B-ready
# 26       NaN  KitKat Einzelriegel Classic 4-Finger-Riegel
# 27       NaN                          Knoppers NussRiegel
# 28       NaN                                  Daim Riegel
# 29       NaN                                       Hanuta
# 30       NaN                               Milka und Oreo
# 31       NaN                                     Knoppers
# 32       NaN                                       Douplo
# 33       NaN                               Kinder Country
# 34       NaN                                Kinder Riegel
# 35       NaN                                    Yogurette
# 36       NaN                                 Kinder bueno
# Fotos    NaN                                          NaN
#
#                                Hersteller  Kalorien in kcal
# 0       Ludwig Schokolade GmbH und Co. KG             467.0
# 1       Ludwig Schokolade GmbH und Co. KG             452.0
# 2       Ludwig Schokolade GmbH und Co. KG             481.0
# 3       Ludwig Schokolade GmbH und Co. KG             484.0
# 4       Ludwig Schokolade GmbH und Co. KG             485.0
# 5       Ludwig Schokolade GmbH und Co. KG             486.0
# 6       Ludwig Schokolade GmbH und Co. KG             499.0
# 7                             Mister Choc             459.0
# 8                             Mister Choc             500.0
# 9                               Choco Fun             450.0
# 10                            Choco Bella             484.0
# 11                              Choco Fun             498.0
# 12                              Choco Fun             498.0
# 13                            Choco Bella             500.0
# 14      Ludwig Schokolade GmbH und Co. KG             459.0
# 15     Natra Chocolate International S.L.             504.0
# 16     Natra Chocolate International S.L.             512.0
# 17                                HG GmbH             530.0
# 18                              Mars GmbH             449.0
# 19                              MARS GmbH             451.0
# 20                              Mars GmbH             481.0
# 21                                 Nestlé             485.0
# 22                              Mars GmbH             487.0
# 23                              Mars GmbH             492.0
# 24                                 Nestlé             492.0
# 25                                Ferrero             521.0
# 26                                 Nestlé             521.0
# 27                                 Storck             535.0
# 28                               Mondelez             536.0
# 29                                Ferrero             542.0
# 30                               Mondelez             548.0
# 31                                 Storck             551.0
# 32                                Ferrero             555.0
# 33                                Ferrero             561.0
# 34                                Ferrero             566.0
# 35                                Ferrero             571.0
# 36                                Ferrero             572.0
# Fotos                                 NaN               NaN

# %%
data.drop(['Fotos'], inplace=True)

# %%
data
# Out:
#     Fotos                                         Name  \
# 0     NaN                                         Race
# 1     NaN                                   Choco Bits
# 2     NaN                                 Coconut Bits
# 3     NaN                                       GET'IT
# 4     NaN                                  Crispy Bits
# 5     NaN                                Hazelnut Bits
# 6     NaN                                  Peanut Bits
# 7     NaN                              Choco & Caramel
# 8     NaN                               Peanut & Choco
# 9     NaN                         Smooth Caramel Bites
# 10    NaN                                Caramel Choco
# 11    NaN                      Caramel & Biscuts Bites
# 12    NaN                      Peanuts & Caramel Bites
# 13    NaN                                 Peanut Choco
# 14    NaN                                       Creamy
# 15    NaN                                Peanuts MINIS
# 16    NaN                                  SIMBA minis
# 17    NaN                              Crack 'n' Snack
# 18    NaN                                         Mars
# 19    NaN                                     MILKYWAY
# 20    NaN                                     Snickers
# 21    NaN                                   Lion White
# 22    NaN                                       Bounty
# 23    NaN                                         Twix
# 24    NaN                                         Nuts
# 25    NaN                              nutella B-ready
# 26    NaN  KitKat Einzelriegel Classic 4-Finger-Riegel
# 27    NaN                          Knoppers NussRiegel
# 28    NaN                                  Daim Riegel
# 29    NaN                                       Hanuta
# 30    NaN                               Milka und Oreo
# 31    NaN                                     Knoppers
# 32    NaN                                       Douplo
# 33    NaN                               Kinder Country
# 34    NaN                                Kinder Riegel
# 35    NaN                                    Yogurette
# 36    NaN                                 Kinder bueno
#
#                             Hersteller  Kalorien in kcal
# 0    Ludwig Schokolade GmbH und Co. KG             467.0
# 1    Ludwig Schokolade GmbH und Co. KG             452.0
# 2    Ludwig Schokolade GmbH und Co. KG             481.0
# 3    Ludwig Schokolade GmbH und Co. KG             484.0
# 4    Ludwig Schokolade GmbH und Co. KG             485.0
# 5    Ludwig Schokolade GmbH und Co. KG             486.0
# 6    Ludwig Schokolade GmbH und Co. KG             499.0
# 7                          Mister Choc             459.0
# 8                          Mister Choc             500.0
# 9                            Choco Fun             450.0
# 10                         Choco Bella             484.0
# 11                           Choco Fun             498.0
# 12                           Choco Fun             498.0
# 13                         Choco Bella             500.0
# 14   Ludwig Schokolade GmbH und Co. KG             459.0
# 15  Natra Chocolate International S.L.             504.0
# 16  Natra Chocolate International S.L.             512.0
# 17                             HG GmbH             530.0
# 18                           Mars GmbH             449.0
# 19                           MARS GmbH             451.0
# 20                           Mars GmbH             481.0
# 21                              Nestlé             485.0
# 22                           Mars GmbH             487.0
# 23                           Mars GmbH             492.0
# 24                              Nestlé             492.0
# 25                             Ferrero             521.0
# 26                              Nestlé             521.0
# 27                              Storck             535.0
# 28                            Mondelez             536.0
# 29                             Ferrero             542.0
# 30                            Mondelez             548.0
# 31                              Storck             551.0
# 32                             Ferrero             555.0
# 33                             Ferrero             561.0
# 34                             Ferrero             566.0
# 35                             Ferrero             571.0
# 36                             Ferrero             572.0

# %% [markdown]
# ## Export CSV without Index and comma-separated

# %%
data.to_csv("Data.csv", sep=",", index=False)

# %% [markdown]
# ## Export XLSX without Index and comma-separated

# %%
data.to_excel("Data.xlsx", index=False)
