# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Alle Daten

# %%
#data = pd.read_excel("karneval-kalorien_bereinigt_mit_Hersteller.xlsx")

# %% [markdown]
# # Ausgewählte Daten inkl. fotos

# %%
data = pd.read_excel("Data.xlsx")

# %%
data.head()
# Out:
#   Supermarkt                         Hersteller          Name  \
# 0       Aldi  Ludwig Schokolade GmbH und Co. KG          Race
# 1       Aldi  Ludwig Schokolade GmbH und Co. KG    Choco Bits
# 2       Aldi  Ludwig Schokolade GmbH und Co. KG  Coconut Bits
# 3       Aldi  Ludwig Schokolade GmbH und Co. KG        GET'IT
# 4       Aldi  Ludwig Schokolade GmbH und Co. KG   Crispy Bits
#
#    davon Zucker in g  Fett in g  Kalorien in kcal  Unnamed: 6  Unnamed: 7  \
# 0               56.8       19.7               467         NaN         NaN
# 1               64.2       16.3               452         NaN         NaN
# 2               48.1       24.7               481         NaN         NaN
# 3               44.0       23.0               484         NaN         NaN
# 4               51.0       24.0               485         NaN         NaN
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         NaN         NaN          NaN          NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 19
# 0          NaN
# 1         16.3
# 2          NaN
# 3          NaN
# 4          NaN

# %%
#data = data[['Name','Hersteller', 'Kalorien in kcal']]

# %%
#data = data.reindex(data.index.rename(['Platzierung']))

# %%
#data.index = data['Name']

# %%
#data.drop(columns=data['data'], axis=1)

# %% [markdown]
# ## Name/Rename Index

# %%
#data.index.name = 'Index'

# %%
#data.set_index(data['Name'])

# %% [markdown]
# ## Get Length of Pandas Rows

# %%
len(data.index)
# Out:
# 37

# %% [markdown]
# ## Add Foto-Columns

# %%
#data['Fotos'] = "" #np.arange(len(data.index))

# %%
data.head()
# Out:
#   Supermarkt                         Hersteller          Name  \
# 0       Aldi  Ludwig Schokolade GmbH und Co. KG          Race
# 1       Aldi  Ludwig Schokolade GmbH und Co. KG    Choco Bits
# 2       Aldi  Ludwig Schokolade GmbH und Co. KG  Coconut Bits
# 3       Aldi  Ludwig Schokolade GmbH und Co. KG        GET'IT
# 4       Aldi  Ludwig Schokolade GmbH und Co. KG   Crispy Bits
#
#    davon Zucker in g  Fett in g  Kalorien in kcal  Unnamed: 6  Unnamed: 7  \
# 0               56.8       19.7               467         NaN         NaN
# 1               64.2       16.3               452         NaN         NaN
# 2               48.1       24.7               481         NaN         NaN
# 3               44.0       23.0               484         NaN         NaN
# 4               51.0       24.0               485         NaN         NaN
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         NaN         NaN          NaN          NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 19
# 0          NaN
# 1         16.3
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# ## Add Fotos

# %%
#data['Fotos'] = data.Fotos.apply(lambda x: "https://bilder.ams3.cdn.digitaloceanspaces.com/Aldi_SelectionMini_Chrispy-Bits__DSC1486.jpg")
#data.at[0, 'Fotos'] = "https://bilder.ams3.cdn.digitaloceanspaces.com/Aldi_SelectionMini_Chrispy-Bits__DSC1486.jpg"
#data.at[1, 'Fotos'] = "https://bilder.ams3.cdn.digitaloceanspaces.com/LIDL_MC_Choco_Caramel_DSC1480.jpg"
#data.at[2, 'Fotos'] = "https://bilder.ams3.cdn.digitaloceanspaces.com/Aldi_Peanut-Bits_DSC1491.jpg"

# %%
data.loc['Fotos'] = np.nan
# Out:
# /Users/mstauber/Data/Anaconda/anaconda/envs/data/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# ## Change https to http

# %%
#data['Foto'] = data.Foto.apply(lambda x: x.replace("https", "http"))

# %% [markdown]
# ## Result

# %%
data.head()
# Out:
#   Supermarkt                         Hersteller          Name  \
# 0       Aldi  Ludwig Schokolade GmbH und Co. KG          Race
# 1       Aldi  Ludwig Schokolade GmbH und Co. KG    Choco Bits
# 2       Aldi  Ludwig Schokolade GmbH und Co. KG  Coconut Bits
# 3       Aldi  Ludwig Schokolade GmbH und Co. KG        GET'IT
# 4       Aldi  Ludwig Schokolade GmbH und Co. KG   Crispy Bits
#
#    davon Zucker in g  Fett in g  Kalorien in kcal  Unnamed: 6  Unnamed: 7  \
# 0               56.8       19.7               467         NaN         NaN
# 1               64.2       16.3               452         NaN         NaN
# 2               48.1       24.7               481         NaN         NaN
# 3               44.0       23.0               484         NaN         NaN
# 4               51.0       24.0               485         NaN         NaN
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         NaN         NaN          NaN          NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 19
# 0          NaN
# 1         16.3
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# ## Rearrange Columns

# %%
data = data[['Name','Hersteller','Kalorien in kcal', 'Fett in g']]

# %%
data
# Out:
#                                            Name  \
# 0                                          Race
# 1                                    Choco Bits
# 2                                  Coconut Bits
# 3                                        GET'IT
# 4                                   Crispy Bits
# 5                                 Hazelnut Bits
# 6                                   Peanut Bits
# 7                               Choco & Caramel
# 8                                Peanut & Choco
# 9                          Smooth Caramel Bites
# 10                                Caramel Choco
# 11                      Caramel & Biscuts Bites
# 12                      Peanuts & Caramel Bites
# 13                                 Peanut Choco
# 14                                       Creamy
# 15                                Peanuts MINIS
# 16                                  SIMBA minis
# 17                              Crack 'n' Snack
# 18                                         Mars
# 19                                     MILKYWAY
# 20                                     Snickers
# 21                                   Lion White
# 22                                       Bounty
# 23                                         Twix
# 24                                         Nuts
# 25                              nutella B-ready
# 26  KitKat Einzelriegel Classic 4-Finger-Riegel
# 27                          Knoppers NussRiegel
# 28                                  Daim Riegel
# 29                                       Hanuta
# 30                               Milka und Oreo
# 31                                     Knoppers
# 32                                       Douplo
# 33                               Kinder Country
# 34                                Kinder Riegel
# 35                                    Yogurette
# 36                                 Kinder bueno
#
#                             Hersteller  Kalorien in kcal  Fett in g
# 0    Ludwig Schokolade GmbH und Co. KG               467       19.7
# 1    Ludwig Schokolade GmbH und Co. KG               452       16.3
# 2    Ludwig Schokolade GmbH und Co. KG               481       24.7
# 3    Ludwig Schokolade GmbH und Co. KG               484       23.0
# 4    Ludwig Schokolade GmbH und Co. KG               485       24.0
# 5    Ludwig Schokolade GmbH und Co. KG               486       25.0
# 6    Ludwig Schokolade GmbH und Co. KG               499       27.9
# 7                          Mister Choc               459       20.0
# 8                          Mister Choc               500       28.0
# 9                            Choco Fun               450       19.0
# 10                         Choco Bella               484       23.0
# 11                           Choco Fun               498       25.0
# 12                           Choco Fun               498       27.0
# 13                         Choco Bella               500       28.0
# 14   Ludwig Schokolade GmbH und Co. KG               459       20.0
# 15  Natra Chocolate International S.L.               504       28.0
# 16  Natra Chocolate International S.L.               512       25.0
# 17                             HG GmbH               530       29.0
# 18                           Mars GmbH               449       16.6
# 19                           MARS GmbH               451       17.0
# 20                           Mars GmbH               481       23.0
# 21                              Nestlé               485       22.3
# 22                           Mars GmbH               487       26.0
# 23                           Mars GmbH               492       24.0
# 24                              Nestlé               492       24.7
# 25                             Ferrero               521       27.0
# 26                              Nestlé               521       27.6
# 27                              Storck               535       31.8
# 28                            Mondelez               536       31.0
# 29                             Ferrero               542       31.9
# 30                            Mondelez               548       33.0
# 31                              Storck               551       33.2
# 32                             Ferrero               555       33.5
# 33                             Ferrero               561       33.8
# 34                             Ferrero               566       35.0
# 35                             Ferrero               571       35.6
# 36                             Ferrero               572       37.3

# %%
#data.drop(['Fotos'], inplace=True)

# %%
data
# Out:
#                                            Name  \
# 0                                          Race
# 1                                    Choco Bits
# 2                                  Coconut Bits
# 3                                        GET'IT
# 4                                   Crispy Bits
# 5                                 Hazelnut Bits
# 6                                   Peanut Bits
# 7                               Choco & Caramel
# 8                                Peanut & Choco
# 9                          Smooth Caramel Bites
# 10                                Caramel Choco
# 11                      Caramel & Biscuts Bites
# 12                      Peanuts & Caramel Bites
# 13                                 Peanut Choco
# 14                                       Creamy
# 15                                Peanuts MINIS
# 16                                  SIMBA minis
# 17                              Crack 'n' Snack
# 18                                         Mars
# 19                                     MILKYWAY
# 20                                     Snickers
# 21                                   Lion White
# 22                                       Bounty
# 23                                         Twix
# 24                                         Nuts
# 25                              nutella B-ready
# 26  KitKat Einzelriegel Classic 4-Finger-Riegel
# 27                          Knoppers NussRiegel
# 28                                  Daim Riegel
# 29                                       Hanuta
# 30                               Milka und Oreo
# 31                                     Knoppers
# 32                                       Douplo
# 33                               Kinder Country
# 34                                Kinder Riegel
# 35                                    Yogurette
# 36                                 Kinder bueno
#
#                             Hersteller  Kalorien in kcal  Fett in g
# 0    Ludwig Schokolade GmbH und Co. KG               467       19.7
# 1    Ludwig Schokolade GmbH und Co. KG               452       16.3
# 2    Ludwig Schokolade GmbH und Co. KG               481       24.7
# 3    Ludwig Schokolade GmbH und Co. KG               484       23.0
# 4    Ludwig Schokolade GmbH und Co. KG               485       24.0
# 5    Ludwig Schokolade GmbH und Co. KG               486       25.0
# 6    Ludwig Schokolade GmbH und Co. KG               499       27.9
# 7                          Mister Choc               459       20.0
# 8                          Mister Choc               500       28.0
# 9                            Choco Fun               450       19.0
# 10                         Choco Bella               484       23.0
# 11                           Choco Fun               498       25.0
# 12                           Choco Fun               498       27.0
# 13                         Choco Bella               500       28.0
# 14   Ludwig Schokolade GmbH und Co. KG               459       20.0
# 15  Natra Chocolate International S.L.               504       28.0
# 16  Natra Chocolate International S.L.               512       25.0
# 17                             HG GmbH               530       29.0
# 18                           Mars GmbH               449       16.6
# 19                           MARS GmbH               451       17.0
# 20                           Mars GmbH               481       23.0
# 21                              Nestlé               485       22.3
# 22                           Mars GmbH               487       26.0
# 23                           Mars GmbH               492       24.0
# 24                              Nestlé               492       24.7
# 25                             Ferrero               521       27.0
# 26                              Nestlé               521       27.6
# 27                              Storck               535       31.8
# 28                            Mondelez               536       31.0
# 29                             Ferrero               542       31.9
# 30                            Mondelez               548       33.0
# 31                              Storck               551       33.2
# 32                             Ferrero               555       33.5
# 33                             Ferrero               561       33.8
# 34                             Ferrero               566       35.0
# 35                             Ferrero               571       35.6
# 36                             Ferrero               572       37.3

# %% [markdown]
# ## Export CSV without Index and comma-separated

# %%
data.to_csv("Data.csv", sep=",", index=False)

# %% [markdown]
# ## Export XLSX without Index and comma-separated

# %%
data.to_excel("Data.xlsx", index=False)
